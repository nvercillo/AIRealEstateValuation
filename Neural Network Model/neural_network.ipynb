# %%
import pandas as pd
import json
import ast


filename = "housing_data.csv"

# %%
col_list = ["AdditionalFields"]

df = pd.read_csv(filename, usecols=col_list)

k = 0

for i, j in df.iterrows():

    if i == 0:
        a_json = json.loads(j["AdditionalFields"])

        data = ast.literal_eval(a_json)
        a = list(data.items())

        additional_df = pd.DataFrame(a)
        additional_df = additional_df.T

    else:

        a_json = json.loads(j["AdditionalFields"])
        data = ast.literal_eval(a_json)
        a = list(data.values())
        new_row = pd.DataFrame(a).T
        additional_df = additional_df.append(new_row)

    k = k + 1

# %%
new_header = additional_df.iloc[0] 
additional_df = additional_df[1:] 
additional_df.columns = new_header

# %%
additional_df = additional_df.filter(['sold_price', 'sqarefootage','Type','Style','Bedrooms','Bathrooms','Kitchens', 'Rooms', 'Groceries #1 distance',
 'Groceries #2 distance',
 'Groceries #3 distance', 'Restaurants #1 distance',
 'Restaurants #2 distance',
 'Restaurants #3 distance','Coffee #1 distance',
 'Coffee #2 distance',
 'Coffee #3 distance','Gas Station #1 distance',
 'Gas Station #2 distance',
 'Gas Station #3 distance','Medical Care #1 distance',
 'Medical Care #2 distance',
 'Medical Care #3 distance','Park #1 distance',
 'Park #2 distance',
 'Park #3 distance','Library #1 distance',
 'Library #2 distance',
 'Library #3 distance','Pharmacy #1 distance',
 'Pharmacy #2 distance',
 'Pharmacy #3 distance','Mall #1 distance',
 'Mall #2 distance',
 'Mall #3 distance'])

additional_df
# Out:
# 0  sold_price sqarefootage             Type        Style Bedrooms Bathrooms  \
# 1     526,800      500-599        Condo Apt    Apartment        1         1
# 0   1,805,000          n/a         Detached  Backsplit 4        3         2
# 0   1,300,000          n/a    Semi-Detached     2-Storey        3         2
# 0   1,250,000          n/a    Semi-Detached     2-Storey        3         2
# 0   2,025,000          n/a         Detached     3-Storey        4         4
# ..        ...          ...              ...          ...      ...       ...
# 0     965,500     700-1100         Detached     Bungalow        2         2
# 0     594,000      900-999        Condo Apt    Apartment        2         2
# 0     471,000    1200-1399  Condo Townhouse     2-Storey        3         2
# 0     770,000      900-999  Condo Townhouse    Apartment        2         2
# 0     839,900      700-799        Condo Apt    Apartment        2         2
#
# 0  Kitchens Rooms Groceries #1 distance Groceries #2 distance  ...  \
# 1         1     4                  0.44                   0.6  ...
# 0         1     8                  0.73                  0.81  ...
# 0         1     6                  0.66                  0.68  ...
# 0         1     7                  0.74                  1.07  ...
# 0         1    10                  0.81                  1.03  ...
# ..      ...   ...                   ...                   ...  ...
# 0         1     5                  1.29                  1.82  ...
# 0         1     5                  0.31                  0.95  ...
# 0         1     8                  0.84                  1.55  ...
# 0         1     6                  0.42                  0.89  ...
# 0         1     5                  0.51                  1.24  ...
#
# 0  Park #3 distance Library #1 distance Library #2 distance  \
# 1              1.31                1.21                1.26
# 0              1.03                 2.5                2.56
# 0              0.69                1.05                1.06
# 0              3.18                 0.6                 0.6
# 0              1.73                0.78                0.78
# ..              ...                 ...                 ...
# 0              1.23                 0.4                0.41
# 0              2.85                0.42                0.42
# 0              1.23                0.77                1.61
# 0              1.34                1.44                1.42
# 0              1.34                2.17                2.18
#
# 0  Library #3 distance Pharmacy #1 distance Pharmacy #2 distance  \
# 1                 1.26                 0.14                 0.39
# 0                 2.56                 0.73                 1.26
# 0                 1.26                 0.43                 0.44
# 0                  0.6                 0.29                 1.97
# 0                 1.19                 1.99                 1.86
# ..                 ...                  ...                  ...
# 0                 1.89                 0.53                 1.55
# 0                  2.2                 0.46                 1.59
# 0                 1.62                 1.18                 1.74
# 0                 1.42                 0.87                 1.45
# 0                 2.38                 2.18                 2.21
#
# 0  Pharmacy #3 distance Mall #1 distance Mall #2 distance Mall #3 distance
# 1                  1.17             1.22             1.46                2
# 0                  1.39             1.36             1.79             1.79
# 0                  1.54             0.63             0.73             2.82
# 0                  2.68             3.33             5.09             4.63
# 0                   1.9             2.49              2.7             2.49
# ..                  ...              ...              ...              ...
# 0                  1.78             1.75             1.95             4.47
# 0                  1.59             2.36             2.96             3.02
# 0                  2.09              1.3             1.48             2.21
# 0                  1.45              0.7             1.37              1.9
# 0                  3.86             2.04             2.07             2.11
#
# [8584 rows x 35 columns]

# %%
ar = ['Groceries #1 distance',
 'Groceries #2 distance',
 'Groceries #3 distance', 'Restaurants #1 distance',
 'Restaurants #2 distance',
 'Restaurants #3 distance','Coffee #1 distance',
 'Coffee #2 distance',
 'Coffee #3 distance','Gas Station #1 distance',
 'Gas Station #2 distance',
 'Gas Station #3 distance','Medical Care #1 distance',
 'Medical Care #2 distance',
 'Medical Care #3 distance','Park #1 distance',
 'Park #2 distance',
 'Park #3 distance','Library #1 distance',
 'Library #2 distance',
 'Library #3 distance','Pharmacy #1 distance',
 'Pharmacy #2 distance',
 'Pharmacy #3 distance','Mall #1 distance',
 'Mall #2 distance',
 'Mall #3 distance']
# len(X)
for field in ar:
    additional_df = additional_df[additional_df[field] != "km"]
    

additional_df = additional_df[additional_df["sqarefootage"] != "n/a"]

# %%
X = additional_df.drop(['sold_price'],axis=1)
Y = additional_df.filter(['sold_price'])

# %%
# new_header = additional_df.iloc[0] 
# additional_df = additional_df[1:] 
# additional_df.columns = new_header 

# additional_df = additional_df.filter(['sold_price', 'sqarefootage','Type','Style','Bedrooms','Bathrooms','Kitchens', 'Rooms', 'Groceries #1 distance',
#  'Groceries #2 distance',
#  'Groceries #3 distance', 'Restaurants #1 distance',
#  'Restaurants #2 distance',
#  'Restaurants #3 distance','Coffee #1 distance',
#  'Coffee #2 distance',
#  'Coffee #3 distance','Gas Station #1 distance',
#  'Gas Station #2 distance',
#  'Gas Station #3 distance','Medical Care #1 distance',
#  'Medical Care #2 distance',
#  'Medical Care #3 distance','Park #1 distance',
#  'Park #2 distance',
#  'Park #3 distance','Library #1 distance',
#  'Library #2 distance',
#  'Library #3 distance','Pharmacy #1 distance',
#  'Pharmacy #2 distance',
#  'Pharmacy #3 distance','Mall #1 distance',
#  'Mall #2 distance',
#  'Mall #3 distance'])

# additional_df
# # list(additional_df)



# # len(X)
# ar = ['Groceries #1 distance',
#  'Groceries #2 distance',
#  'Groceries #3 distance', 'Restaurants #1 distance',
#  'Restaurants #2 distance',
#  'Restaurants #3 distance','Coffee #1 distance',
#  'Coffee #2 distance',
#  'Coffee #3 distance','Gas Station #1 distance',
#  'Gas Station #2 distance',
#  'Gas Station #3 distance','Medical Care #1 distance',
#  'Medical Care #2 distance',
#  'Medical Care #3 distance','Park #1 distance',
#  'Park #2 distance',
#  'Park #3 distance','Library #1 distance',
#  'Library #2 distance',
#  'Library #3 distance','Pharmacy #1 distance',
#  'Pharmacy #2 distance',
#  'Pharmacy #3 distance','Mall #1 distance',
#  'Mall #2 distance',
#  'Mall #3 distance']
# # len(X)
# for field in ar:
#     additional_df = additional_df[additional_df[field] != "km"]



# X = additional_df.drop(['sold_price'],axis=1)
# Y = additional_df.filter(['sold_price'])
# # Y
# list(X)

# %%
additional_df.head()
# Out:
# 0 sold_price sqarefootage       Type        Style Bedrooms Bathrooms Kitchens  \
# 1    526,800      500-599  Condo Apt    Apartment        1         1        1
# 0    507,000      600-699  Condo Apt    Apartment        1         1        1
# 0    465,000      800-899  Condo Apt    Apartment        2         2        1
# 0    630,000      800-899  Condo Apt    Apartment        2         2        1
# 0    682,000      500-599  Condo Apt  Multi-Level        1         1        1
#
# 0 Rooms Groceries #1 distance Groceries #2 distance  ... Park #3 distance  \
# 1     4                  0.44                   0.6  ...             1.31
# 0     5                  0.12                  0.13  ...             1.62
# 0     5                  1.32                  2.01  ...             1.65
# 0     5                  0.88                  1.59  ...             1.76
# 0     5                  0.28                  0.38  ...             0.61
#
# 0 Library #1 distance Library #2 distance Library #3 distance  \
# 1                1.21                1.26                1.26
# 0                1.19                1.19                1.53
# 0                0.78                0.83                2.15
# 0                1.33                1.33                1.33
# 0                0.58                   1                1.25
#
# 0 Pharmacy #1 distance Pharmacy #2 distance Pharmacy #3 distance  \
# 1                 0.14                 0.39                 1.17
# 0                 0.86                 1.66                 1.82
# 0                 2.48                 2.07                 2.32
# 0                 1.74                 2.53                 2.48
# 0                 0.38                 0.96                 1.29
#
# 0 Mall #1 distance Mall #2 distance Mall #3 distance
# 1             1.22             1.46                2
# 0             1.74             4.03             4.14
# 0             2.36             3.04             3.22
# 0             1.55             1.61             1.84
# 0             0.36             0.78             1.27
#
# [5 rows x 35 columns]

# %%
len(X)
# Out:
# 5317

# %%
X.infer_objects().dtypes
# Out:
# 0
# sqarefootage                object
# Type                        object
# Style                       object
# Bedrooms                    object
# Bathrooms                   object
# Kitchens                    object
# Rooms                       object
# Groceries #1 distance       object
# Groceries #2 distance       object
# Groceries #3 distance       object
# Restaurants #1 distance     object
# Restaurants #2 distance     object
# Restaurants #3 distance     object
# Coffee #1 distance          object
# Coffee #2 distance          object
# Coffee #3 distance          object
# Gas Station #1 distance     object
# Gas Station #2 distance     object
# Gas Station #3 distance     object
# Medical Care #1 distance    object
# Medical Care #2 distance    object
# Medical Care #3 distance    object
# Park #1 distance            object
# Park #2 distance            object
# Park #3 distance            object
# Library #1 distance         object
# Library #2 distance         object
# Library #3 distance         object
# Pharmacy #1 distance        object
# Pharmacy #2 distance        object
# Pharmacy #3 distance        object
# Mall #1 distance            object
# Mall #2 distance            object
# Mall #3 distance            object
# dtype: object

# %%
fields = [[ 'Bedrooms','Bathrooms','Kitchens', 'Rooms', 'Groceries #1 distance',
 'Groceries #2 distance',
 'Groceries #3 distance', 'Restaurants #1 distance',
 'Restaurants #2 distance',
 'Restaurants #3 distance','Coffee #1 distance',
 'Coffee #2 distance',
 'Coffee #3 distance','Gas Station #1 distance',
 'Gas Station #2 distance',
 'Gas Station #3 distance','Medical Care #1 distance',
 'Medical Care #2 distance',
 'Medical Care #3 distance','Park #1 distance',
 'Park #2 distance',
 'Park #3 distance','Library #1 distance',
 'Library #2 distance',
 'Library #3 distance','Pharmacy #1 distance',
 'Pharmacy #2 distance',
 'Pharmacy #3 distance','Mall #1 distance',
 'Mall #2 distance',
 'Mall #3 distance']]


for field in fields:
    X[field] = X[field].astype(str).astype(float)

# %%
X.infer_objects().dtypes
# Out:
# 0
# sqarefootage                 object
# Type                         object
# Style                        object
# Bedrooms                    float64
# Bathrooms                   float64
# Kitchens                    float64
# Rooms                       float64
# Groceries #1 distance       float64
# Groceries #2 distance       float64
# Groceries #3 distance       float64
# Restaurants #1 distance     float64
# Restaurants #2 distance     float64
# Restaurants #3 distance     float64
# Coffee #1 distance          float64
# Coffee #2 distance          float64
# Coffee #3 distance          float64
# Gas Station #1 distance     float64
# Gas Station #2 distance     float64
# Gas Station #3 distance     float64
# Medical Care #1 distance    float64
# Medical Care #2 distance    float64
# Medical Care #3 distance    float64
# Park #1 distance            float64
# Park #2 distance            float64
# Park #3 distance            float64
# Library #1 distance         float64
# Library #2 distance         float64
# Library #3 distance         float64
# Pharmacy #1 distance        float64
# Pharmacy #2 distance        float64
# Pharmacy #3 distance        float64
# Mall #1 distance            float64
# Mall #2 distance            float64
# Mall #3 distance            float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

d={}

print(len(X.columns))

for i in range(len(X.columns)):
    #if column is categorical
    if type(X.iloc[0,i])==str:
        print("categorical")
        print(X.iloc[0,i])

        le = LabelEncoder()
        X[X.columns[i]] = le.fit_transform(X[X.columns[i]])
        
        print(le.classes_)
        
        print(X[X.columns[i]])
        series = X[X.columns[i]]
        
        d[series.name] = {}
        
        le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
        
        d[series.name] = le_name_mapping
# Out:
# 34
# categorical
# 500-599
# ['0-499' '1' '1000-1199' '1100-1299' '1100-1500' '1200-1399' '1400-1599'
#  '1500-2000' '1600-1799' '1800-1999' '2000-2249' '2000-2500' '2250-2499'
#  '2500-2749' '2500-3000' '2750-2999' '3000-3249' '3000-3500' '3500-5000'
#  '500-599' '5000+' '600-699' '700-1100' '700-799' '700-899' '800-899' '9'
#  '900-1099' '900-999' '< 700']
# 1    19
# 0    21
# 0    25
# 0    25
# 0    19
#      ..
# 0    22
# 0    28
# 0     5
# 0    28
# 0    23
# Name: sqarefootage, Length: 5317, dtype: int64
# categorical
# Condo Apt
# ['Att/Row/Twnhouse' 'Co-Op Apt' 'Co-Ownership Apt' 'Comm Element Condo'
#  'Condo Apt' 'Condo Townhouse' 'Det Condo' 'Detached' 'Duplex' 'Link'
#  'Multiplex' 'Other' 'Semi-Det Condo' 'Semi-Detached' 'Store W/Apt/Offc'
#  'Triplex']
# 1    4
# 0    4
# 0    4
# 0    4
# 0    4
#     ..
# 0    7
# 0    4
# 0    5
# 0    5
# 0    4
# Name: Type, Length: 5317, dtype: int64
# categorical
# Apartment
# ['1' '1 1/2 Storey' '2 1/2 Storey' '2-Storey' '3' '3-Storey' 'Apartment'
#  'Bachelor/Studio' 'Backsplit 3' 'Backsplit 4' 'Backsplit 5' 'Bungaloft'
#  'Bungalow' 'Bungalow-Raised' 'Loft' 'Multi-Level' 'Other' 'Sidesplit 3'
#  'Sidesplit 4' 'Sidesplit 5' 'Stacked Townhse']
# 1     6
# 0     6
# 0     6
# 0     6
# 0    15
#      ..
# 0    12
# 0     6
# 0     3
# 0     6
# 0     6
# Name: Style, Length: 5317, dtype: int64

# %%
Y['sold_price'] = Y['sold_price'].str.replace(',', '').astype(float)


yScaler = StandardScaler()
yScaler.fit(Y)
Y = yScaler.transform(Y)

# %%
from sklearn.model_selection import train_test_split

Xtr,Xts,Ytr,Yts = train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
from tensorflow import keras
import keras_tuner as kt
import tensorflow as tf
from keras_tuner import Hyperband,RandomSearch
import keras_tuner
from tensorflow.keras import layers
import numpy as np

from tensorflow.keras.callbacks import EarlyStopping

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=[Xtr.shape[1]]),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.mean_squared_error,
              metrics=['mean_squared_error'])



train_x = np.asarray(Xtr)
train_y = np.asarray(Ytr)
# validation_x = np.asarray(validation_x)
# validation_y = np.asarray(validation_y)


model.fit(train_x, train_y, epochs=500)
# Out:
# Epoch 1/500
# 133/133 [==============================] - 0s 1ms/step - loss: 1.8485 - mean_squared_error: 1.8485
# Epoch 2/500
# 133/133 [==============================] - 0s 998us/step - loss: 0.6044 - mean_squared_error: 0.6044
# Epoch 3/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.3743 - mean_squared_error: 0.3743
# Epoch 4/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.3214 - mean_squared_error: 0.3214
# Epoch 5/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2834 - mean_squared_error: 0.2834
# Epoch 6/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.3353 - mean_squared_error: 0.3353
# Epoch 7/500
# 133/133 [==============================] - 0s 996us/step - loss: 0.2435 - mean_squared_error: 0.2435
# Epoch 8/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2664 - mean_squared_error: 0.2664
# Epoch 9/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2495 - mean_squared_error: 0.2495
# Epoch 10/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2484 - mean_squared_error: 0.2484
# Epoch 11/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2510 - mean_squared_error: 0.2510
# Epoch 12/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2218 - mean_squared_error: 0.2218
# Epoch 13/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2269 - mean_squared_error: 0.2269
# Epoch 14/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2532 - mean_squared_error: 0.2532
# Epoch 15/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2317 - mean_squared_error: 0.2317
# Epoch 16/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2519 - mean_squared_error: 0.2519
# Epoch 17/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2324 - mean_squared_error: 0.2324
# Epoch 18/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2288 - mean_squared_error: 0.2288
# Epoch 19/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2692 - mean_squared_error: 0.2692
# Epoch 20/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2625 - mean_squared_error: 0.2625
# Epoch 21/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2005 - mean_squared_error: 0.2005
# Epoch 22/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.2432 - mean_squared_error: 0.2432
# Epoch 23/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.
500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1224 - mean_squared_error: 0.1224
# Epoch 469/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1125 - mean_squared_error: 0.1125
# Epoch 470/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1022 - mean_squared_error: 0.1022
# Epoch 471/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0981 - mean_squared_error: 0.0981
# Epoch 472/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1001 - mean_squared_error: 0.1001
# Epoch 473/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1100 - mean_squared_error: 0.1100
# Epoch 474/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1209 - mean_squared_error: 0.1209
# Epoch 475/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1010 - mean_squared_error: 0.1010
# Epoch 476/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1235 - mean_squared_error: 0.1235
# Epoch 477/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1112 - mean_squared_error: 0.1112
# Epoch 478/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1251 - mean_squared_error: 0.1251
# Epoch 479/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0992 - mean_squared_error: 0.0992
# Epoch 480/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1113 - mean_squared_error: 0.1113
# Epoch 481/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1097 - mean_squared_error: 0.1097
# Epoch 482/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1037 - mean_squared_error: 0.1037
# Epoch 483/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0952 - mean_squared_error: 0.0952
# Epoch 484/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1160 - mean_squared_error: 0.1160
# Epoch 485/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1147 - mean_squared_error: 0.1147
# Epoch 486/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.0928 - mean_squared_error: 0.0928
# Epoch 487/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1036 - mean_squared_error: 0.1036
# Epoch 488/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.0986 - mean_squared_error: 0.0986
# Epoch 489/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1091 - mean_squared_error: 0.1091
# Epoch 490/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1010 - mean_squared_error: 0.1010
# Epoch 491/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0891 - mean_squared_error: 0.0891
# Epoch 492/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.0981 - mean_squared_error: 0.0981
# Epoch 493/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.0915 - mean_squared_error: 0.0915
# Epoch 494/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.0935 - mean_squared_error: 0.0935
# Epoch 495/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1107 - mean_squared_error: 0.1107
# Epoch 496/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1087 - mean_squared_error: 0.1087
# Epoch 497/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1093 - mean_squared_error: 0.1093
# Epoch 498/500
# 133/133 [==============================] - 0s 1ms/step - loss: 0.1142 - mean_squared_error: 0.1142
# Epoch 499/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1184 - mean_squared_error: 0.1184
# Epoch 500/500
# 133/133 [==============================] - 0s 2ms/step - loss: 0.1032 - mean_squared_error: 0.1032

# %%
callback = EarlyStopping(monitor='val_mean_absolute_error', patience=10, verbose=1)



# Creating custom R^2 performance metric for keras models
def r2(y_true,y_pred):
    from keras import backend as K
    SS_res = K.sum(K.square(y_true-y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return (1 - SS_res/(SS_tot + K.epsilon()))

def model_builder(hp):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=[train_x.shape[1]]))
    for i in range(hp.Int("num_layers", 2, 10)): #number of layers
        model.add(
            layers.Dense(
                units=hp.Int("units_" + str(i), min_value=32, max_value=512, step=32), #number of units
                activation="relu",
            )
        )
    model.add(keras.layers.Dense(1))
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
    model.compile(
        optimizer=keras.optimizers.Adam(hp.Choice("learning_rate", [1e-2, 1e-3, 1e-4])),
                loss=keras.losses.mean_absolute_error,
              metrics=['mean_squared_error',r2,keras.losses.mean_absolute_error])
    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective=keras_tuner.Objective("val_r2", direction="max"),
                     max_epochs=1000,
                     executions_per_trial=1,
                     overwrite=True,
                     directory="my_dir",
                     project_name="KerasRegressor",
                    
)

# %%
tuner.search(train_x, train_y, epochs=1000, validation_split=0.2,callbacks=[callback])
# Out:
# Search: Running Trial #1
#
# Hyperparameter    |Value             |Best Value So Far
# num_layers        |3                 |?
# units_0           |256               |?
# units_1           |288               |?
# learning_rate     |0.0001            |?
# tuner/epochs      |2                 |?
# tuner/initial_e...|0                 |?
# tuner/bracket     |6                 |?
# tuner/round       |0                 |?
#
# Epoch 1/2
# ---------------------------------------------------------------------------
# StagingError                              Traceback (most recent call last)
# /var/folders/1f/gzrgws6s3bbfv99j9mptfmm40000gn/T/ipykernel_29038/2729327212.py in <module>
# ----> 1 tuner.search(train_x, train_y, epochs=1000, validation_split=0.2,callbacks=[callback])
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras_tuner/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     177
#     178             self.on_trial_begin(trial)
# --> 179             results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     180             # `results` is None indicates user updated oracle in `run_trial()`.
#     181             if results is None:
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras_tuner/tuners/hyperband.py in run_trial(self, trial, *fit_args, **fit_kwargs)
#     374             fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     375             fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 376         return super(Hyperband, self).run_trial(trial, *fit_args, **fit_kwargs)
#     377
#     378     def _build_model(self, hp):
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras_tuner/engine/tuner.py in run_trial(self, trial, *args, **kwargs)
#     302             callbacks.append(model_checkpoint)
#     303             copied_kwargs["callbacks"] = callbacks
# --> 304             obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     305
#     306             # objective left unspecified,
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras_tuner/engine/tuner.py in _build_and_fit_model(self, trial, *args, **kwargs)
#     232         hp = trial.hyperparameters
#     233         model = self._try_build(hp)
# --> 234         return self.hypermodel.fit(hp, model, *args, **kwargs)
#     235
#     236     def run_trial(self, trial, *args, **kwargs):
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras_tuner/engine/hypermodel.py in fit(self, hp, model, *args, **kwargs)
#     135             If return a float, it should be the `objective` value.
#     136         """
# --> 137         return model.fit(*args, **kwargs)
#     138
#     139
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     869       # This is the first call of __call__, so we have to initialize.
#     870       initializers = []
# --> 871       self._initialize(args, kwds, add_initializers_to=initializers)
#     872     finally:
#     873       # At this point we know that the initialization is complete (or less
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     723     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     724     self._concrete_stateful_fn = (
# --> 725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     726             *args, **kwds))
#     727
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3194     arg_names = base_arg_names + missing_arg_names
#    3195     graph_function = ConcreteFunction(
# -> 3196         func_graph_module.func_graph_from_py_func(
#    3197             self._name,
#    3198             self._python_function,
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# ~/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# StagingError: in user code:
#
#     /Users/juliuskapeniak/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:805 train_function  *
#         return step_function(self, iterator)
#     /var/folders/1f/gzrgws6s3bbfv99j9mptfmm40000gn/T/ipykernel_29038/4181169171.py:7 r2  *
#         from keras import backend as K
#     /Users/juliuskapeniak/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras/__init__.py:25 <module>
#         from keras import models
#     /Users/juliuskapeniak/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras/models.py:19 <module>
#         from keras import backend
#     /Users/juliuskapeniak/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/keras/backend.py:39 <module>
#         from tensorflow.python.eager.context import get_config
#
#     ImportError: cannot import name 'get_config' from 'tensorflow.python.eager.context' (/Users/juliuskapeniak/finalTerm4020/AIRealEstateValuation/VENV/lib/python3.8/site-packages/tensorflow/python/eager/context.py)

# %%
bestHparams=tuner.get_best_hyperparameters(num_trials=1)[0]

models_hyper = tuner.get_best_models(num_models=2)
best_model = models_hyper[0]
score = best_model.evaluate(Xts, Yts, verbose=0)

# %%
model = tuner.hypermodel.build(bestHparams)
model.fit(X, Y, epochs=50, validation_split=0.2)

model.save("./models/amenity_model")
